# %%
import pandas as pd

# %%
df = pd.read_csv("Companies.csv", on_bad_lines = "skip")

# %% [markdown]
# How data look like?

# %%
df
# Out:
#     name                                                                              \
# 0    TCS                                           ...
# 1    Infosys                                       ...
# 2    Genpact                                       ...
# 3    Concentrix Corporation                        ...
# 4    Bharti Airtel                                 ...
# ..                                                 ...
# 365  Micromax Informatics                          ...
# 366  AM Infoweb                                    ...
# 367  Haldiram Snacks                               ...
# 368  WPP Media                                     ...
# 369  Bharat Fritz Werner                           ...
#
#       rating   reviews  \
# 0        3.3   (1.1L)
# 1        3.5   (49k)
# 2        3.6   (42.5k)
# 3        3.6   (32.4k)
# 4        3.8   (17.1k)
# ..       ...       ...
# 365      3.9   (567)
# 366      3.8   (558)
# 367      3.9   (558)
# 368      3.6   (558)
# 369      3.9   (555)
#
#      Type_Location                                                                       \
# 0     IT Services & Consulting | Bengaluru +444 oth...
# 1     IT Services & Consulting | Bengaluru +246 oth...
# 2     Analytics & KPO | Hyderabad +181 other locati...
# 3     BPO | Bengaluru +183 other locations         ...
# 4     Telecom | Gurugram +794 other locations      ...
# ..                                                 ...
# 365   Consumer Electronics & Appliances | New Delhi...
# 366   BPO | Pune +8 other locations                ...
# 367   Food Processing | Noida +69 other locations  ...
# 368   Marketing & Advertising | Gurugram +27 other ...
# 369   Industrial Machinery | Bengaluru +18 other lo...
#
#           Top_rated_for
# 0          Job Security
# 1          Job Security
# 2          Job Security
# 3          Job Security
# 4            Promotions
# ..                  ...
# 365   Work Life Balance
# 366   Skill Development
# 367          Promotions
# 368        Job Security
# 369   Skill Development
#
# [370 rows x 5 columns]

# %% [markdown]
# How big is the Data?

# %%
df.shape
# Out:
# (370, 5)

# %% [markdown]
# What is the data type of columns?

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 5 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   name                                                                                 370 non-null    str
#  1    rating                                                                              370 non-null    float64
#  2    reviews                                                                             370 non-null    str
#  3    Type_Location                                                                       370 non-null    str
#  4    Top_rated_for                                                                       370 non-null    str
# dtypes: float64(1), str(4)
# memory usage: 81.2 KB

# %% [markdown]
# Are there is missing values?

# %%
df.isnull().sum()
# Out:
# name                                                                                   0
#  rating                                                                                0
#  reviews                                                                               0
#  Type_Location                                                                         0
#  Top_rated_for                                                                         0
# dtype: int64

# %% [markdown]
# how does data look mathematically?

# %%
df.describe()
# Out:
#            rating
# count  370.000000
# mean     3.730541
# std      0.146549
# min      3.000000
# 25%      3.700000
# 50%      3.800000
# 75%      3.800000
# max      4.000000

# %% [markdown]
# Are there duplicate Values?

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates()
# Out:
#     name                                                                              \
# 0    TCS                                           ...
# 1    Infosys                                       ...
# 2    Genpact                                       ...
# 3    Concentrix Corporation                        ...
# 4    Bharti Airtel                                 ...
# ..                                                 ...
# 365  Micromax Informatics                          ...
# 366  AM Infoweb                                    ...
# 367  Haldiram Snacks                               ...
# 368  WPP Media                                     ...
# 369  Bharat Fritz Werner                           ...
#
#       rating   reviews  \
# 0        3.3   (1.1L)
# 1        3.5   (49k)
# 2        3.6   (42.5k)
# 3        3.6   (32.4k)
# 4        3.8   (17.1k)
# ..       ...       ...
# 365      3.9   (567)
# 366      3.8   (558)
# 367      3.9   (558)
# 368      3.6   (558)
# 369      3.9   (555)
#
#      Type_Location                                                                       \
# 0     IT Services & Consulting | Bengaluru +444 oth...
# 1     IT Services & Consulting | Bengaluru +246 oth...
# 2     Analytics & KPO | Hyderabad +181 other locati...
# 3     BPO | Bengaluru +183 other locations         ...
# 4     Telecom | Gurugram +794 other locations      ...
# ..                                                 ...
# 365   Consumer Electronics & Appliances | New Delhi...
# 366   BPO | Pune +8 other locations                ...
# 367   Food Processing | Noida +69 other locations  ...
# 368   Marketing & Advertising | Gurugram +27 other ...
# 369   Industrial Machinery | Bengaluru +18 other lo...
#
#           Top_rated_for
# 0          Job Security
# 1          Job Security
# 2          Job Security
# 3          Job Security
# 4            Promotions
# ..                  ...
# 365   Work Life Balance
# 366   Skill Development
# 367          Promotions
# 368        Job Security
# 369   Skill Development
#
# [369 rows x 5 columns]

# %% [markdown]
# How is the correlation between columns?

# %%
df.corr
# Out:
# <bound method DataFrame.corr of     name                                                                              \
# 0    TCS                                           ...
# 1    Infosys                                       ...
# 2    Genpact                                       ...
# 3    Concentrix Corporation                        ...
# 4    Bharti Airtel                                 ...
# ..                                                 ...
# 365  Micromax Informatics                          ...
# 366  AM Infoweb                                    ...
# 367  Haldiram Snacks                               ...
# 368  WPP Media                                     ...
# 369  Bharat Fritz Werner                           ...
#
#       rating   reviews  \
# 0        3.3   (1.1L)
# 1        3.5   (49k)
# 2        3.6   (42.5k)
# 3        3.6   (32.4k)
# 4        3.8   (17.1k)
# ..       ...       ...
# 365      3.9   (567)
# 366      3.8   (558)
# 367      3.9   (558)
# 368      3.6   (558)
# 369      3.9   (555)
#
#      Type_Location                                                                       \
# 0     IT Services & Consulting | Bengaluru +444 oth...
# 1     IT Services & Consulting | Bengaluru +246 oth...
# 2     Analytics & KPO | Hyderabad +181 other locati...
# 3     BPO | Bengaluru +183 other locations         ...
# 4     Telecom | Gurugram +794 other locations      ...
# ..                                                 ...
# 365   Consumer Electronics & Appliances | New Delhi...
# 366   BPO | Pune +8 other locations                ...
# 367   Food Processing | Noida +69 other locations  ...
# 368   Marketing & Advertising | Gurugram +27 other ...
# 369   Industrial Machinery | Bengaluru +18 other lo...
#
#           Top_rated_for
# 0          Job Security
# 1          Job Security
# 2          Job Security
# 3          Job Security
# 4            Promotions
# ..                  ...
# 365   Work Life Balance
# 366   Skill Development
# 367          Promotions
# 368        Job Security
# 369   Skill Development
#
# [370 rows x 5 columns]>
