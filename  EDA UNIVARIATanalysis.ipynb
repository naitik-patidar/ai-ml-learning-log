# %%
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv("Titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# # 1. Categorical Data

# %%
#df.sample(5)

# %% [markdown]
# ## a. Countplot

# %%
#sns.countplot(data = df, x = "Survived")
df["Survived"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(data = df , x = "Pclass").plot(kind = "bar")
# Out:
# []

# %% [markdown]
# b. Pie Chart

# %%
df["Pclass"].value_counts().plot(kind = "pie", autopct = "%.1f%%")
# Out:
# <Axes: >

# %% [markdown]
# # Numicral Data

# %% [markdown]
# a. Histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["Age"], bins = 10)
# Out:
# (array([16., 16., 71., 97., 43., 37., 25., 17.,  9.,  1.]),
#  array([ 0.17 ,  7.753, 15.336, 22.919, 30.502, 38.085, 45.668, 53.251,
#         60.834, 68.417, 76.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# b. distplot

# %%
sns.distplot(df["Age"])
# Out:
# /var/folders/2g/vcqv7bvn1xq6yxx44z_fdbr40000gn/T/ipykernel_35592/2732350774.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# c. Boxplot

# %%
sns.boxplot(df["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
df["Age"].min()
# Out:
# 0.17

# %%
df["Age"].max()
# Out:
# 76.0

# %%
df["Age"].mean()
# Out:
# np.float64(30.272590361445783)

# %%
df["Age"].skew()
# Out:
# np.float64(0.4573612871503845)
