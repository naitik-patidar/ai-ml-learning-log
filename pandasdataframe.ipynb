# %% [markdown]
# ##DataFrame

# %%
import numpy as np 
import pandas as pd

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

pd.DataFrame(data)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns = ['Name','Age', 'City', 'Salary']
df2 = pd.DataFrame(data_list, columns=columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# ##Indexing

# %%
df2["Name"]
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: str

# %%
df2[["Name", "City", 'Salary']]
# Out:
#     Name      City  Salary
# 0   John  New York   65000
# 1   Anna     Paris   70000
# 2  Peter    Berlin   62000
# 3  Linda    London   85000

# %%
df2["Designation"] = ['Engineer', 'Manager','Doctor', 'Analyst']

df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000    Engineer
# 1   Anna   34     Paris   70000     Manager
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000     Analyst

# %%
df2.drop("Designation", axis=1, inplace = True)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[2]
# Out:
# Name       Peter
# Age           29
# City      Berlin
# Salary     62000
# Name: 2, dtype: object

# %%
df2.loc[[2,3]][["Name", "Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# ### Condition Statements

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# #only people whos age is above 30

# %%
df2[df2["Age"] > 30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
# PERSON HAS TO BE FROM NEW YORK
df2[df2["City"] == 'New York']
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000

# %%
#age above 30 and city london
df2[(df2["Age"] > 30) & (df2['City'] == "London")]
# Out:
#     Name  Age    City  Salary
# 3  Linda   42  London   85000
