# %% [markdown]
# ===========================================Pandas===============================================

# %%
import numpy as np
import pandas as pd

# %%
label = [ 'a', 'b', 'c' ]
my_list = [10,20,30]
arr = np.array([1,2,3])
d = {'b':10,'s':20,'d':30}

pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list, index = label)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series((d))
# Out:
# b    10
# s    20
# d    30
# dtype: int64

# %%
pd.Series(label)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: str
